# %%
# %matplotlib inline
from numpy import *
import matplotlib.pyplot as plt
from PlotFuncs import FigSetup, AxionPhoton, MySaveFig, BlackHoleSpins, FilledLimit

# %%
fig,ax = FigSetup(Shape='Rectangular',ylab='$\epsilon_m$',mathpazo=True)

AxionPhoton.RedGiant(ax)
AxionPhoton.ADMX_res(ax)
AxionPhoton.HAYSTAC_res(ax)
AxionPhoton.QUAX_res(ax)
AxionPhoton.RadioPulsar(ax)
AxionPhoton.ClusterMagneticFields(ax)
AxionPhoton.ISMCoherentMagneticFields(ax)
 

MySaveFig(fig,'mDM_response_ Haloscopes')

# %%
fig,ax = FigSetup(Shape='Rectangular',ylab='$g_{a\gamma\gamma}$',mathpazo=True)

AxionPhoton.Haloscopes(ax)
